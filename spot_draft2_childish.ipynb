# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

import pandas as pd
import numpy as np
import config
from spotipy.oauth2 import SpotifyClientCredentials
import requests, json, time, datetime

# %%
client_id = config.client_id
client_secret = config.secret

client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
name = 'Bruno Mars'
result = sp.search(name)
result['tracks']['items'][0]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#     'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#     'id': '0du5cEVh5yTK9QJze8zA0C',
#     'name': 'Bruno Mars',
#     'type': 'artist',
#     'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#   'available_markets': ['AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
# ...

# %%
#extract Artist URI
artist_uri = result['tracks']['items'][0]['artists'][0]['uri']
artist_uri
# Out:
# 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'

# %%
albums0 = sp.artist_albums(artist_uri, album_type = 'album')
albums1 = albums0['items'] 

album_uri = []
album_name = []

for z in range(len(albums1)):
    album_uri.append(albums1[z]['uri'])
    album_name.append(albums1[z]['name'])

# %%
range(len(albums1))
# Out:
# range(0, 9)

# %%
album_name
# Out:
# ['An Evening With Silk Sonic',
#  'An Evening With Silk Sonic',
#  '24K Magic',
#  'Unorthodox Jukebox (Deluxe Edition)',
#  'Unorthodox Jukebox',
#  'Unorthodox Jukebox',
#  'Unorthodox Jukebox',
#  'Doo-Wops & Hooligans',
#  'Doo-Wops & Hooligans']

# %%
album1_practice = sp.album_tracks(album_uri[2])

# %%
range(len(album1_practice))
# Out:
# range(0, 7)

# %%
p_track_number = []
p_track_name = []
p_track_uri = []

for z in range(len(album1_practice)):
    p_track_number.append(album1_practice['items'][z]['track_number'])
    p_track_name.append(album1_practice['items'][z]['name'])
    p_track_uri.append(album1_practice['items'][z]['uri'])

# %%
p_track_name
# Out:
# ['24K Magic',
#  'Chunky',
#  'Perm',
#  "That's What I Like",
#  'Versace on the Floor',
#  'Straight up & Down',
#  'Calling All My Lovelies']

# %%
track_number = []
track_name = []
track_uri = []


for z in range(len(album_uri)):
    track_numer.

# %%
album_stuff
# Out:
# {'href': 'https://api.spotify.com/v1/albums/5qteDmbjYSYe4lxOYSwjoj/tracks?offset=0&limit=50',
#  'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/73sIBHcqh3Z3NyqHKZ7FOL'},
#      'href': 'https://api.spotify.com/v1/artists/73sIBHcqh3Z3NyqHKZ7FOL',
#      'id': '73sIBHcqh3Z3NyqHKZ7FOL',
#      'name': 'Childish Gambino',
#      'type': 'artist',
#      'uri': 'spotify:artist:73sIBHcqh3Z3NyqHKZ7FOL'}],
#    'available_markets': ['AU', 'NZ'],
#    'disc_number': 1,
#    'duration_ms': 179386,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0Y1WFTsjpgH5fbtcOrcYCN'},
#    'href': 'https://api.spotify.com/v1/tracks/0Y1WFTsjpgH5fbtcOrcYCN',
#    'id': '0Y1WFTsjpgH5fbtcOrcYCN',
#    'is_local': False,
#    'name': '0.00',
#    'preview_url': 'https://p.scdn.co/mp3-preview/976fefe810d7f75195ff377e88f7e60ea055de17?cid=a957a43f5e484f5582cce432dc53546b',
#    'track_number': 1,
#    'type': 'track',
# ...

# %%
def gather_album_stuff(uri)




gather_album_stuff()
